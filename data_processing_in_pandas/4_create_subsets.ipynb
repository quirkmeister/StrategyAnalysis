# %%
# Dependencies

import pandas as pd
import numpy as np
import glob
import os
import timeit                                # To check performance

# %%
# import clean CSV file to master CSV file

tic = timeit.default_timer()                            # Monitor performance

citibike_rides_df = pd.read_csv("../2_clean_datasets_by_year/rides_2013-2021.csv", index_col=None, header=0)

toc = timeit.default_timer()                            # Monitor performance
print(f'Time (in seconds) to export unified CSV file: {round(toc - tic, 2)}')

citibike_rides_df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3,7,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Time (in seconds) to export unified CSV file: 2438.47
#            Duration (Sec)    Start Time & Date      End Time & Date  \
# 0                   695.0  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1                   693.0  2013-06-01 00:00:08  2013-06-01 00:11:41
# 2                  2059.0  2013-06-01 00:00:44  2013-06-01 00:35:03
# 3                   123.0  2013-06-01 00:01:04  2013-06-01 00:03:07
# 4                  1521.0  2013-06-01 00:01:22  2013-06-01 00:26:43
# ...                   ...                  ...                  ...
# 122697047           769.0  2021-06-30 13:13:05  2021-06-30 13:25:54
# 122697048           310.0  2021-06-23 22:51:46  2021-06-23 22:56:56
# 122697049           874.0  2021-06-19 16:18:58  2021-06-19 16:33:32
# 122697050            82.0  2021-06-23 11:29:37  2021-06-23 11:30:59
# 122697051           498.0  2021-06-19 00:54:21  2021-06-19 01:02:39
#
#           Start Station ID          Start Station Name  Start Lat  Start Lon  \
# 0                      444          Broadway & W 24 St  40.742354 -73.989151
# 1                      444          Broadway & W 24 St  40.742354 -73.989151
# 2                      406      Hicks St & Montague St  40.695128 -73.995951
# 3                      475         E 15 St & Irving Pl  40.735243 -73.987586
# 4                     2008       Little West St & 1 Pl  40.705693 -74.016777
# ...                    ...                         ...        ...        ...
# 122697047          7712.04    Alexander Ave & E 134 St  40.807466 -73.927107
# 122697048          6450.05             8 Ave & W 31 St  40.750585 -73.994685
# 122697049          4354.05  S Portland Ave & Hanson Pl  40.685396 -73.974315
# 122697050          6450.05             8 Ave & W 31 St  40.750585 -73.994685
# 122697051          6450.05             8 Ave & W 31 St  40.750585 -73.994684
#
#           End Station ID               End Station Name    End Lat    End Lon  \
# 0                    434                9 Ave & W 18 St  40.743174 -74.003664
# 1                    434                9 Ave & W 18 St  40.743174 -74.003664
# 2                    406         Hicks St & Montague St  40.695128 -73.995951
# 3                    262                Washington Park  40.691782 -73.973730
# 4                    310            State St & Smith St  40.689269 -73.989129
# ...                  ...                            ...        ...        ...
# 122697047         7756.1    St. Nicholas Ave & W 126 St  40.811432 -73.951878
# 122697048        6224.05                W 20 St & 8 Ave  40.743453 -74.000040
# 122697049        3928.08  Eastern Pkwy & Washington Ave  40.671649 -73.963115
# 122697050        6450.12                8 Ave & W 33 St  40.751551 -73.993934
# 122697051        6224.05                W 20 St & 8 Ave  40.743453 -74.000040
#
#            Bike ID   User Type  Birth Year   Gender   Age
# 0          19678.0  Subscriber      1983.0     Male  30.0
# 1          16649.0  Subscriber      1984.0     Male  29.0
# 2          19599.0    Customer         NaN  Unknown   NaN
# 3          16352.0  Subscriber      1960.0     Male  53.0
# 4          15567.0  Subscriber      1983.0     Male  30.0
# ...            ...         ...         ...      ...   ...
# 122697047      NaN    Customer         NaN      NaN   NaN
# 122697048      NaN  Subscriber         NaN      NaN   NaN
# 122697049      NaN    Customer         NaN      NaN   NaN
# 122697050      NaN  Subscriber         NaN      NaN   NaN
# 122697051      NaN  Subscriber         NaN      NaN   NaN
#
# [122697052 rows x 16 columns]

# %% [markdown]
# # Create manageable data sets
#
# - oneInHundred (1% the size of the original database. Takes every hundredth row)
# - oneInThousand (.1% the size of the original database. Takes every hundredth row)

# %%
oneInHundred = []
lngth = len(citibike_rides_df)
for i in range(lngth):
    if i%100==0: oneInHundred.append(i)

citibike_rides_df_oneInHundred = citibike_rides_df.iloc[oneInHundred, :].copy()

citibike_rides_df_oneInHundred
# Out:
#            Duration (Sec)    Start Time & Date      End Time & Date  \
# 0                   695.0  2013-06-01 00:00:01  2013-06-01 00:11:36
# 100                 547.0  2013-06-01 00:38:58  2013-06-01 00:48:05
# 200                2436.0  2013-06-01 01:28:02  2013-06-01 02:08:38
# 300                 451.0  2013-06-01 02:39:30  2013-06-01 02:47:01
# 400                7510.0  2013-06-01 06:15:54  2013-06-01 08:21:04
# ...                   ...                  ...                  ...
# 122696600           133.0  2021-06-28 16:22:22  2021-06-28 16:24:35
# 122696700           230.0  2021-06-30 13:03:32  2021-06-30 13:07:22
# 122696800          2690.0  2021-06-29 11:19:00  2021-06-29 12:03:50
# 122696900          2380.0  2021-06-16 18:30:21  2021-06-16 19:10:01
# 122697000          1080.0  2021-06-04 08:03:33  2021-06-04 08:21:33
#
#           Start Station ID              Start Station Name  Start Lat  \
# 0                      444              Broadway & W 24 St  40.742354
# 100                    441                 E 52 St & 2 Ave  40.756014
# 200                    323     Lawrence St & Willoughby St  40.692362
# 300                    280                 E 10 St & 5 Ave  40.733320
# 400                    233  Cadman Plaza W & Pierrepont St  40.694757
# ...                    ...                             ...        ...
# 122696600          6569.07                 W 36 St & 9 Ave  40.754623
# 122696700          6569.07                 W 36 St & 9 Ave  40.754623
# 122696800          5096.11            Pearl St & Peck Slip  40.708485
# 122696900          7059.08          West End Ave & W 60 St  40.772370
# 122697000          6115.09                W 15 St & 10 Ave  40.742753
#
#            Start Lon End Station ID              End Station Name    End Lat  \
# 0         -73.989151            434               9 Ave & W 18 St  40.743174
# 100       -73.967416            383    Greenwich Ave & Charles St  40.735238
# 200       -73.986317            420  Clermont Ave & Lafayette Ave  40.687645
# 300       -73.995101            237               E 11 St & 2 Ave  40.730473
# 400       -73.990527           2006        Central Park S & 6 Ave  40.765909
# ...              ...            ...                           ...        ...
# 122696600 -73.995168        6450.12               8 Ave & W 33 St  40.751551
# 122696700 -73.995168        6450.12               8 Ave & W 33 St  40.751551
# 122696800 -74.002751        4781.03        Concord St & Bridge St  40.697666
# 122696900 -73.990050        4781.03        Concord St & Bridge St  40.697666
# 122697000 -74.007473        4781.03        Concord St & Bridge St  40.697666
#
#              End Lon  Bike ID   User Type  Birth Year   Gender   Age
# 0         -74.003664  19678.0  Subscriber      1983.0     Male  30.0
# 100       -74.000271  17183.0  Subscriber      1967.0     Male  46.0
# 200       -73.969689  14776.0  Subscriber      1982.0     Male  31.0
# 300       -73.986724  20341.0  Subscriber      1961.0     Male  52.0
# 400       -73.976342  19916.0    Customer         NaN  Unknown   NaN
# ...              ...      ...         ...         ...      ...   ...
# 122696600 -73.993934      NaN  Subscriber         NaN      NaN   NaN
# 122696700 -73.993934      NaN  Subscriber         NaN      NaN   NaN
# 122696800 -73.984764      NaN  Subscriber         NaN      NaN   NaN
# 122696900 -73.984764      NaN    Customer         NaN      NaN   NaN
# 122697000 -73.984764      NaN  Subscriber         NaN      NaN   NaN
#
# [1226971 rows x 16 columns]

# %%
# Export clean CSV file to master CSV file

tic = timeit.default_timer()                            # Monitor performance

citibike_rides_df_oneInHundred.to_csv("../2_clean_datasets_by_year/rides_2013-2021_oneInHundred.csv", index=False) 

toc = timeit.default_timer()                            # Monitor performance
print(f'Time (in seconds) to export unified CSV file: {round(toc - tic, 2)}')

citibike_rides_df_oneInHundred.head()
# Out:
# Time (in seconds) to export unified CSV file: 21.62
#      Duration (Sec)    Start Time & Date      End Time & Date  \
# 0             695.0  2013-06-01 00:00:01  2013-06-01 00:11:36
# 100           547.0  2013-06-01 00:38:58  2013-06-01 00:48:05
# 200          2436.0  2013-06-01 01:28:02  2013-06-01 02:08:38
# 300           451.0  2013-06-01 02:39:30  2013-06-01 02:47:01
# 400          7510.0  2013-06-01 06:15:54  2013-06-01 08:21:04
#
#     Start Station ID              Start Station Name  Start Lat  Start Lon  \
# 0                444              Broadway & W 24 St  40.742354 -73.989151
# 100              441                 E 52 St & 2 Ave  40.756014 -73.967416
# 200              323     Lawrence St & Willoughby St  40.692362 -73.986317
# 300              280                 E 10 St & 5 Ave  40.733320 -73.995101
# 400              233  Cadman Plaza W & Pierrepont St  40.694757 -73.990527
#
#     End Station ID              End Station Name    End Lat    End Lon  \
# 0              434               9 Ave & W 18 St  40.743174 -74.003664
# 100            383    Greenwich Ave & Charles St  40.735238 -74.000271
# 200            420  Clermont Ave & Lafayette Ave  40.687645 -73.969689
# 300            237               E 11 St & 2 Ave  40.730473 -73.986724
# 400           2006        Central Park S & 6 Ave  40.765909 -73.976342
#
#      Bike ID   User Type  Birth Year   Gender   Age
# 0    19678.0  Subscriber      1983.0     Male  30.0
# 100  17183.0  Subscriber      1967.0     Male  46.0
# 200  14776.0  Subscriber      1982.0     Male  31.0
# 300  20341.0  Subscriber      1961.0     Male  52.0
# 400  19916.0    Customer         NaN  Unknown   NaN

# %%
oneInThousand = []
lngth = len(citibike_rides_df)
for i in range(lngth):
    if i%1000==0: oneInThousand.append(i)

citibike_rides_df_oneInThousand = citibike_rides_df.iloc[oneInThousand, :].copy()

citibike_rides_df_oneInThousand
# Out:
#            Duration (Sec)    Start Time & Date      End Time & Date  \
# 0                   695.0  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1000               1854.0  2013-06-01 10:03:33  2013-06-01 10:34:27
# 2000               4310.0  2013-06-01 12:20:04  2013-06-01 13:31:54
# 3000                844.0  2013-06-01 13:55:28  2013-06-01 14:09:32
# 4000                215.0  2013-06-01 15:21:42  2013-06-01 15:25:17
# ...                   ...                  ...                  ...
# 122693000           877.0  2021-06-30 10:35:32  2021-06-30 10:50:09
# 122694000          1312.0  2021-06-16 14:55:22  2021-06-16 15:17:14
# 122695000          1522.0  2021-06-13 14:39:05  2021-06-13 15:04:27
# 122696000          1579.0  2021-06-14 19:02:21  2021-06-14 19:28:40
# 122697000          1080.0  2021-06-04 08:03:33  2021-06-04 08:21:33
#
#           Start Station ID     Start Station Name  Start Lat  Start Lon  \
# 0                      444     Broadway & W 24 St  40.742354 -73.989151
# 1000                   217          Old Fulton St  40.702772 -73.993836
# 2000                   304  Broadway & Battery Pl  40.704633 -74.013617
# 3000                   479        9 Ave & W 45 St  40.760193 -73.991255
# 4000                   294    Washington Square E  40.730494 -73.995721
# ...                    ...                    ...        ...        ...
# 122693000          6450.05        8 Ave & W 31 St  40.750585 -73.994685
# 122694000          5506.14      E 6 St & Avenue D  40.722280 -73.976687
# 122695000          5980.07     E 17 St & Broadway  40.737049 -73.990092
# 122696000          6569.07        W 36 St & 9 Ave  40.754623 -73.995167
# 122697000          6115.09       W 15 St & 10 Ave  40.742753 -74.007473
#
#           End Station ID         End Station Name    End Lat    End Lon  \
# 0                    434          9 Ave & W 18 St  40.743174 -74.003664
# 1000                 461          E 20 St & 2 Ave  40.735877 -73.982050
# 2000                 530         11 Ave & W 59 St  40.771522 -73.990541
# 3000                 442          W 27 St & 7 Ave  40.746647 -73.993915
# 4000                 403           E 2 St & 2 Ave  40.725029 -73.990697
# ...                  ...                      ...        ...        ...
# 122693000        5679.05  Mercer St & Bleecker St  40.727064 -73.996621
# 122694000        6422.09          E 44 St & 2 Ave  40.751184 -73.971387
# 122695000        5445.02  Suffolk St & Stanton St  40.720664 -73.985180
# 122696000         7293.1       E 88 St & Park Ave  40.781411 -73.955959
# 122697000        4781.03   Concord St & Bridge St  40.697666 -73.984764
#
#            Bike ID   User Type  Birth Year   Gender   Age
# 0          19678.0  Subscriber      1983.0     Male  30.0
# 1000       16988.0  Subscriber      1949.0   Female  64.0
# 2000       16950.0    Customer         NaN  Unknown   NaN
# 3000       17840.0  Subscriber      1969.0   Female  44.0
# 4000       16519.0  Subscriber      1983.0     Male  30.0
# ...            ...         ...         ...      ...   ...
# 122693000      NaN    Customer         NaN      NaN   NaN
# 122694000      NaN  Subscriber         NaN      NaN   NaN
# 122695000      NaN  Subscriber         NaN      NaN   NaN
# 122696000      NaN  Subscriber         NaN      NaN   NaN
# 122697000      NaN  Subscriber         NaN      NaN   NaN
#
# [122698 rows x 16 columns]

# %%
# Export clean CSV file to master CSV file

tic = timeit.default_timer()                            # Monitor performance

citibike_rides_df_oneInThousand.to_csv("../2_clean_datasets_by_year/rides_2013-2021_oneInThousand.csv", index=False) 

toc = timeit.default_timer()                            # Monitor performance
print(f'Time (in seconds) to export unified CSV file: {round(toc - tic, 2)}')

citibike_rides_df_oneInThousand.head()
# Out:
# Time (in seconds) to export unified CSV file: 1.93
#       Duration (Sec)    Start Time & Date      End Time & Date  \
# 0              695.0  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1000          1854.0  2013-06-01 10:03:33  2013-06-01 10:34:27
# 2000          4310.0  2013-06-01 12:20:04  2013-06-01 13:31:54
# 3000           844.0  2013-06-01 13:55:28  2013-06-01 14:09:32
# 4000           215.0  2013-06-01 15:21:42  2013-06-01 15:25:17
#
#      Start Station ID     Start Station Name  Start Lat  Start Lon  \
# 0                 444     Broadway & W 24 St  40.742354 -73.989151
# 1000              217          Old Fulton St  40.702772 -73.993836
# 2000              304  Broadway & Battery Pl  40.704633 -74.013617
# 3000              479        9 Ave & W 45 St  40.760193 -73.991255
# 4000              294    Washington Square E  40.730494 -73.995721
#
#      End Station ID  End Station Name    End Lat    End Lon  Bike ID  \
# 0               434   9 Ave & W 18 St  40.743174 -74.003664  19678.0
# 1000            461   E 20 St & 2 Ave  40.735877 -73.982050  16988.0
# 2000            530  11 Ave & W 59 St  40.771522 -73.990541  16950.0
# 3000            442   W 27 St & 7 Ave  40.746647 -73.993915  17840.0
# 4000            403    E 2 St & 2 Ave  40.725029 -73.990697  16519.0
#
#        User Type  Birth Year   Gender   Age
# 0     Subscriber      1983.0     Male  30.0
# 1000  Subscriber      1949.0   Female  64.0
# 2000    Customer         NaN  Unknown   NaN
# 3000  Subscriber      1969.0   Female  44.0
# 4000  Subscriber      1983.0     Male  30.0
